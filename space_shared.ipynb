# %%
from TestSPACE import TestSPACE

# %%
#set total run time
run_time = 10000

# %%
Test1 = {
    "K_sed": 1E-4,
    "K_br": 1E-5,
    "test_name": "Test1",
    "soil_depth": 0.,
    "F_f": 0.,

    "m_sp": 0.5,
    "n_sp":1,
    "rock_uplift_rate":0.0001,
    "sp_crit_sed": 0.0, # threshold
    "sp_crit_br": 0.0, # threshold

    # grid parameters
    "node_spacing": 10,
    "num_rows": 20,
    "num_cols": 20,

    "timestep": 10.0, # timestep size (yrs) . Lower if encountering chaotic results. Can be increased for lower K values.
    "starting_grid":"Test1_t1E4_U0.1_random" # enter name of starting grid folder with .asc files in it
}

# %%
space = TestSPACE(run_time=run_time, **Test1)

# %%
space.run_space()
# Out:
# Elapsed time {} 0
# Elapsed time {} 1000.0
# Elapsed time {} 2000.0
# Elapsed time {} 3000.0
# Elapsed time {} 4000.0
# Elapsed time {} 5000.0
# Elapsed time {} 6000.0
# Elapsed time {} 7000.0
# Elapsed time {} 8000.0
# Elapsed time {} 9000.0

# %%
space.plot()

# %%
space.save_grid()
